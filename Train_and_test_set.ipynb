# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Machine_Learning/blob/main/Train_and_test_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sklearn

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
from sklearn.model_selection import train_test_split
train_set, test_set=train_test_split(df, test_size=0.2, random_state=221)

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2915     -119.06     35.36                 9.0       1228.0           234.0
# 4010     -118.58     34.17                18.0       6476.0          1082.0
# 14286    -117.12     32.72                36.0       6096.0          1285.0
# 17114    -122.16     37.47                44.0       2581.0           437.0
# 3506     -118.45     34.26                35.0       1637.0           300.0
# ...          ...       ...                 ...          ...             ...
# 6005     -117.77     34.07                29.0       2976.0           662.0
# 20361    -118.94     34.17                15.0       1679.0           271.0
# 3954     -118.65     34.20                23.0       7480.0          1084.0
# 12006    -117.52     33.89                 2.0      17978.0          3217.0
# 3916     -118.52     34.19                37.0       1892.0           347.0
#
# ...

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20576    -122.00     38.83                26.0        272.0            49.0
# 2131     -119.71     36.80                17.0       1415.0           267.0
# 5982     -117.75     34.10                21.0       8069.0          2174.0
# 10903    -117.86     33.75                31.0       1761.0           515.0
# 12542    -121.49     38.54                47.0       2313.0           536.0
# ...          ...       ...                 ...          ...             ...
# 19339    -122.79     38.54                 5.0       3986.0           737.0
# 6454     -118.06     34.12                34.0       2941.0           558.0
# 10544    -117.76     33.71                14.0       4321.0           582.0
# 15625    -122.41     37.80                52.0       4088.0           946.0
# 12072    -117.55     33.87                18.0       8136.0          1584.0
#
# ...
