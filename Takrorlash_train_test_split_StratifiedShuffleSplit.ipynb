# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Machine_Learning/blob/main/Takrorlash_train_test_split_StratifiedShuffleSplit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn

# %%
df=pd.read_csv('/content/Korean_demographics_2000-2022.csv', parse_dates=['Date'])

# %%
df.head()
# Out:
#         Date             Region   Birth  Birth_rate   Death  Death_rate  \
# 0 2000-01-01              Busan  3752.0       11.61  1875.0         5.8
# 1 2000-01-01  Chungcheongbuk-do  1903.0       15.06   924.0         7.3
# 2 2000-01-01  Chungcheongnam-do  2398.0       14.75  1466.0         9.0
# 3 2000-01-01              Daegu  3057.0       14.39  1117.0         5.3
# 4 2000-01-01            Daejeon  1859.0       16.08   565.0         4.9
#
#    Divorce  Divorce_rate  Marriage  Marriage_rate  Natural_growth  \
# 0    814.0           2.5    2435.0            7.5          1877.0
# 1    220.0           1.7     828.0            6.6           979.0
# 2    321.0           2.0    1055.0            6.5           932.0
# 3    422.0           2.0    1577.0            7.4          1940.0
# 4    280.0           2.4     868.0            7.5          1294.0
#
#    Natural_growth_rate
# 0                  5.8
# 1                  7.7
# 2                  5.7
# 3                  9.1
# ...

# %%
print(df.at[3, 'Date'].year)
print(df.at[3, 'Date'].month)
print(df.at[3, 'Date'].day)
print(df.at[3, 'Date'].weekday())
# Out:
# 2000
# 1
# 1
# 5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4860 entries, 0 to 4859
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 4860 non-null   datetime64[ns]
#  1   Region               4860 non-null   object
#  2   Birth                4716 non-null   float64
#  3   Birth_rate           4709 non-null   float64
#  4   Death                4716 non-null   float64
#  5   Death_rate           4709 non-null   float64
#  6   Divorce              4716 non-null   float64
#  7   Divorce_rate         4709 non-null   float64
#  8   Marriage             4716 non-null   float64
#  9   Marriage_rate        4709 non-null   float64
#  10  Natural_growth       4716 non-null   float64
#  11  Natural_growth_rate  4709 non-null   float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 455.8+ KB

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
train_df, test_df=train_test_split(df, test_size=0.2, random_state=65)

# %%
test_df
# Out:
#            Date             Region   Birth  Birth_rate   Death  Death_rate  \
# 1993 2009-03-01       Jeollanam-do  1393.0        8.56  1273.0         7.8
# 3006 2013-12-01              Busan  1885.0        6.36  1829.0         6.2
# 1188 2005-07-01              Busan  1898.0        6.12  1418.0         4.6
# 2657 2012-04-01               Jeju   509.0       10.84   260.0         5.5
# 847  2003-12-01  Chungcheongbuk-do  1156.0        9.13   845.0         6.7
# ...         ...                ...     ...         ...     ...         ...
# 1730 2008-01-01  Chungcheongnam-do  1941.0       11.48  1198.0         7.1
# 4429 2020-07-01  Chungcheongbuk-do   712.0        5.30   925.0         6.9
# 59   2000-04-01         Gangwon-do  1612.0       12.65   901.0         7.1
# 2906 2013-06-01   Gyeongsangbuk-do  1634.0        7.42  1544.0         7.0
# 1156 2005-05-01            Daejeon  1164.0        9.45   510.0         4.1
#
# ...

# %%
df.head()
# Out:
#         Date             Region   Birth  Birth_rate   Death  Death_rate  \
# 0 2000-01-01              Busan  3752.0       11.61  1875.0         5.8
# 1 2000-01-01  Chungcheongbuk-do  1903.0       15.06   924.0         7.3
# 2 2000-01-01  Chungcheongnam-do  2398.0       14.75  1466.0         9.0
# 3 2000-01-01              Daegu  3057.0       14.39  1117.0         5.3
# 4 2000-01-01            Daejeon  1859.0       16.08   565.0         4.9
#
#    Divorce  Divorce_rate  Marriage  Marriage_rate  Natural_growth  \
# 0    814.0           2.5    2435.0            7.5          1877.0
# 1    220.0           1.7     828.0            6.6           979.0
# 2    321.0           2.0    1055.0            6.5           932.0
# 3    422.0           2.0    1577.0            7.4          1940.0
# 4    280.0           2.4     868.0            7.5          1294.0
#
#    Natural_growth_rate
# 0                  5.8
# 1                  7.7
# 2                  5.7
# 3                  9.1
# ...

# %%
print(df['Divorce_rate'].max())
print(df['Divorce_rate'].min())
print(df['Divorce_rate'].mean())
# Out:
# 5.0
# 0.8
# 2.351390953493311

# %%
bins=[0.5, 2.0, 3.5, 5.0]
df['Divorce_Category']=pd.cut(df['Divorce_rate'], bins=bins, labels=[1,2,3])

# %%
df.head(10)
# Out:
#         Date             Region    Birth  Birth_rate   Death  Death_rate  \
# 0 2000-01-01              Busan   3752.0       11.61  1875.0         5.8
# 1 2000-01-01  Chungcheongbuk-do   1903.0       15.06   924.0         7.3
# 2 2000-01-01  Chungcheongnam-do   2398.0       14.75  1466.0         9.0
# 3 2000-01-01              Daegu   3057.0       14.39  1117.0         5.3
# 4 2000-01-01            Daejeon   1859.0       16.08   565.0         4.9
# 5 2000-01-01         Gangwon-do   1966.0       14.91  1067.0         8.1
# 6 2000-01-01            Gwangju   2159.0       18.77   606.0         5.3
# 7 2000-01-01        Gyeonggi-do  13527.0       17.85  3770.0         5.0
# 8 2000-01-01   Gyeongsangbuk-do   3362.0       14.14  2230.0         9.4
# 9 2000-01-01   Gyeongsangnam-do   3928.0       15.05  2125.0         8.1
#
#    Divorce  Divorce_rate  Marriage  Marriage_rate  Natural_growth  \
# 0    814.0           2.5    2435.0            7.5          1877.0
# ...

# %%
df['Divorce_Category'].hist()
plt.show()

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                   0
# Region                 0
# Birth                  0
# Birth_rate             0
# Death                  0
# Death_rate             0
# Divorce                0
# Divorce_rate           0
# Marriage               0
# Marriage_rate          0
# Natural_growth         0
# Natural_growth_rate    0
# Divorce_Category       0
# dtype: int64

# %%
from sklearn.model_selection import StratifiedShuffleSplit

sss=StratifiedShuffleSplit(n_splits=1, random_state=65, test_size=0.2)

for train_index, test_index in sss.split(df,df['Divorce_Category']):
  a=train_index
  b=test_index

# %%
len(a)
# Out:
# 3767

# %%
len(b)
# Out:
# 942

# %%
df.head()
# Out:
#         Date             Region   Birth  Birth_rate   Death  Death_rate  \
# 0 2000-01-01              Busan  3752.0       11.61  1875.0         5.8
# 1 2000-01-01  Chungcheongbuk-do  1903.0       15.06   924.0         7.3
# 2 2000-01-01  Chungcheongnam-do  2398.0       14.75  1466.0         9.0
# 3 2000-01-01              Daegu  3057.0       14.39  1117.0         5.3
# 4 2000-01-01            Daejeon  1859.0       16.08   565.0         4.9
#
#    Divorce  Divorce_rate  Marriage  Marriage_rate  Natural_growth  \
# 0    814.0           2.5    2435.0            7.5          1877.0
# 1    220.0           1.7     828.0            6.6           979.0
# 2    321.0           2.0    1055.0            6.5           932.0
# 3    422.0           2.0    1577.0            7.4          1940.0
# 4    280.0           2.4     868.0            7.5          1294.0
#
#    Natural_growth_rate Divorce_Category
# 0                  5.8                2
# 1                  7.7                1
# ...

# %%
df.columns[2:12]
# Out:
# Index(['Birth', 'Birth_rate', 'Death', 'Death_rate', 'Divorce', 'Divorce_rate',
#        'Marriage', 'Marriage_rate', 'Natural_growth', 'Natural_growth_rate'],
#       dtype='object')

# %%
df2=df[['Birth','Birth_rate','Death','Death_rate','Divorce','Divorce_rate','Marriage','Marriage_rate','Natural_growth','Natural_growth_rate']]

# %%
df2.corr()
# Out:
#                         Birth  Birth_rate     Death  Death_rate   Divorce  \
# Birth                1.000000    0.110002  0.934256   -0.181224  0.974826
# Birth_rate           0.110002    1.000000 -0.045191   -0.341458  0.036455
# Death                0.934256   -0.045191  1.000000   -0.071622  0.960635
# Death_rate          -0.181224   -0.341458 -0.071622    1.000000 -0.168498
# Divorce              0.974826    0.036455  0.960635   -0.168498  1.000000
# Divorce_rate         0.084391    0.356603 -0.000593   -0.186864  0.109055
# Marriage             0.966675    0.050223  0.942114   -0.176636  0.966739
# Marriage_rate        0.148506    0.511153  0.049359   -0.304388  0.114971
# Natural_growth       0.902210    0.278198  0.689094   -0.281653  0.819148
# Natural_growth_rate  0.167821    0.889096  0.002215   -0.733623  0.108527
#
#                      Divorce_rate  Marriage  Marriage_rate  Natural_growth  \
# Birth                    0.084391  0.966675       0.148506        0.902210
# ...
