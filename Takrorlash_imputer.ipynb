# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Machine_Learning/blob/main/Takrorlash_imputer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
URL ="https://github.com/ageron/handson-ml2/blob/master/datasets/housing/housing.csv?raw=true"
df = pd.read_csv(URL)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
bins=[0,1.5, 3.0, 4.5, 6.0, np.inf]
labels=[1,2,3,4,5]
df['income_cat']=pd.cut(df['median_income'], bins=bins, labels=labels)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   income_cat
# 0          5
# 1          5
# 2          5
# ...

# %%
df['income_cat'].value_counts()
# Out:
# income_cat
# 3    7236
# 2    6581
# 4    3639
# 5    2362
# 1     822
# Name: count, dtype: int64

# %%
from sklearn.model_selection import StratifiedShuffleSplit
sss=StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45)

for train_index, test_index in sss.split(df, df['income_cat']):
  train_set=df.loc[train_index]
  test_set=df.loc[train_index]

# %%
train_set.sample(3)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17232    -119.69     34.43                43.0       1257.0           311.0
# 9113     -118.21     34.56                12.0       2472.0           408.0
# 15748    -122.44     37.77                52.0       2705.0           647.0
#
#        population  households  median_income  median_house_value  \
# 17232       671.0       263.0         2.8750            280600.0
# 9113       1048.0       380.0         4.7097            262100.0
# 15748      1355.0       628.0         2.0161            364300.0
#
#       ocean_proximity
# 17232       <1H OCEAN
# 9113           INLAND
# 15748        NEAR BAY

# %%
df.drop(columns='income_cat', inplace=True)

# %%
train_set.drop(columns='income_cat', inplace=True)
test_set.drop(columns='income_cat', inplace=True)

# %%
housing=train_set.copy()
housing_labels=train_set['median_house_value'].copy()
train_set.drop(columns='median_house_value', inplace=True)

# %%
housing2=housing.drop(columns='ocean_proximity')
housing2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16908    -122.37     37.58                34.0       2697.0           313.0
# 634      -122.16     37.71                37.0       1507.0           242.0
# 10909    -117.86     33.74                32.0        691.0           151.0
# 3736     -118.40     34.18                32.0       3724.0           899.0
# 14749    -117.05     32.57                22.0       2857.0           516.0
# ...          ...       ...                 ...          ...             ...
# 1249     -122.09     39.13                28.0       4169.0           895.0
# 1941     -120.97     38.65                 9.0       3707.0           602.0
# 955      -121.93     37.66                24.0       3166.0           424.0
# 6107     -117.90     34.11                37.0       1286.0           255.0
# 12098    -117.34     33.96                15.0       6437.0          1298.0
#
# ...

# %%
housing2.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924991           -0.104731     0.046229
# latitude            -0.924991  1.000000            0.009273    -0.037930
# housing_median_age  -0.104731  0.009273            1.000000    -0.360118
# total_rooms          0.046229 -0.037930           -0.360118     1.000000
# total_bedrooms       0.069228 -0.067314           -0.318354     0.930789
# population           0.098784 -0.108873           -0.293744     0.851353
# households           0.054957 -0.071532           -0.300781     0.918175
# median_income       -0.012543 -0.082782           -0.118303     0.199337
# median_house_value  -0.042491 -0.146351            0.107314     0.134346
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069228    0.098784    0.054957      -0.012543
# latitude                 -0.067314   -0.108873   -0.071532      -0.082782
# ...

# %%
housing2.corrwith(housing2['median_house_value']).sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688185
# total_rooms           0.134346
# housing_median_age    0.107314
# households            0.067504
# total_bedrooms        0.051329
# population           -0.024739
# longitude            -0.042491
# latitude             -0.146351
# dtype: float64

# %%
housing2.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        169
# population              0
# households              0
# median_income           0
# median_house_value      0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='median')

# %%
housing.drop(columns='median_house_value', inplace=True)

# %%
housing=train_set.copy()
housing.head(2)
housing.drop(columns='ocean_proximity', inplace=True)

# %%
imputer.fit(housing)
imputer.statistics_
# Out:
# array([-118.49  ,   34.25  ,   29.    , 2127.    ,  433.    , 1166.    ,
#         409.    ,    3.5377])

# %%
X=imputer.transform(housing)
x=imputer.fit_transform(housing)

# %%
new_housing=pd.DataFrame(x, columns=housing.columns, index=housing.index)
new_housing.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# dtype: int64

# %%
new_housing['ocean_proximity']=train_set['ocean_proximity'].copy()
new_housing.head(2)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16908    -122.37     37.58                34.0       2697.0           313.0
# 634      -122.16     37.71                37.0       1507.0           242.0
#
#        population  households  median_income ocean_proximity
# 16908       810.0       279.0        12.4291      NEAR OCEAN
# 634         632.0       253.0         4.5553        NEAR BAY

# %% [markdown]
# OrdinalEncoder
