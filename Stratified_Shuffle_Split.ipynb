# %% [markdown]
# <a href="https://colab.research.google.com/github/JavZon/Machine_Learning/blob/main/Stratified_Shuffle_Split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sklearn

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
from sklearn.model_selection import train_test_split
train_set, test_set=train_test_split(df, test_size=0.2, random_state=22)

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2115     -119.72     36.76                23.0       6403.0             NaN
# 1985     -120.79     38.70                13.0       5036.0          1034.0
# 4520     -118.20     34.04                18.0        796.0           227.0
# 15323    -117.34     33.21                12.0       5963.0          1372.0
# 12560    -121.46     38.54                48.0       1001.0           205.0
# ...          ...       ...                 ...          ...             ...
# 13970    -116.85     34.26                19.0       5395.0          1220.0
# 9181     -118.55     34.37                21.0       7010.0          1063.0
# 18911    -122.24     38.14                15.0       8479.0          1759.0
# 15956    -122.45     37.71                41.0       1578.0           351.0
# 11125    -117.91     33.84                35.0       1244.0           324.0
#
# ...

# %%
test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13186    -117.69     34.09                28.0       1437.0           295.0
# 4384     -118.27     34.09                44.0       3646.0           912.0
# 16198    -121.27     37.96                43.0       1624.0           448.0
# 7656     -118.26     33.82                28.0       5091.0          1074.0
# 4889     -118.26     34.02                39.0        698.0           232.0
# ...          ...       ...                 ...          ...             ...
# 19042    -121.81     38.49                18.0       4518.0           827.0
# 14987    -117.03     32.73                32.0       1750.0           333.0
# 13756    -117.16     34.06                17.0       2285.0           554.0
# 15457    -117.28     33.18                14.0        676.0           118.0
# 2639     -124.14     40.59                17.0       2985.0           610.0
#
# ...

# %%
list1=np.random.randint(1,100, 28)
list1
# Out:
# array([ 6, 43, 56,  1, 92, 95, 47, 44, 62, 15, 62, 62,  2, 41, 57, 69, 52,
#        28, 39, 39, 24, 79, 33, 95, 78,  6, 78, 81])

# %%
bins=[0,20,40,60,80,100]
cut_bins=pd.cut(list1, bins=bins)

# %%
cut_bins
# Out:
# [(0, 20], (40, 60], (40, 60], (0, 20], (80, 100], ..., (80, 100], (60, 80], (0, 20], (60, 80], (80, 100]]
# Length: 28
# Categories (5, interval[int64, right]): [(0, 20] < (20, 40] < (40, 60] < (60, 80] < (80, 100]]

# %%
df=pd.DataFrame({'Numbers':list1})
df
bins=[0,20,40,60,80,100]
df['Bin_categories']=pd.cut(df['Numbers'], bins=bins)
df['Label_categories']=pd.cut(df['Numbers'], bins=bins, labels=['Worse', 'Bad','Good','Well','Best'])

# %%
df['Label_categories'].value_counts()
# Out:
# Label_categories
# Good     7
# Well     7
# Worse    5
# Bad      5
# Best     4
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Numbers Bin_categories Label_categories
# 0        6        (0, 20]            Worse
# 1       43       (40, 60]             Good
# 2       56       (40, 60]             Good
# 3        1        (0, 20]            Worse
# 4       92      (80, 100]             Best

# %%
bins=[0,1.5, 3.0, 4.5, 6.0, np.inf]
df['income_cat']=pd.cut(df['median_income'], bins=bins, labels=[1,2,3,4,5])
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   income_cat
# 0          5
# 1          5
# 2          5
# ...

# %%
df.loc[[2224,14896,6361,5597,18875]]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2224     -119.82     36.81                25.0       3305.0           551.0
# 14896    -117.07     32.60                18.0       2602.0           551.0
# 6361     -117.97     34.13                33.0       2038.0           473.0
# 5597     -118.23     33.80                26.0        239.0           135.0
# 18875    -122.22     38.07                 4.0      15654.0          2394.0
#
#        population  households  median_income  median_house_value  \
# 2224       1149.0       500.0         5.0698            150900.0
# 14896      1042.0       550.0         1.9267             67500.0
# 6361       1546.0       469.0         3.4777            144500.0
# 5597        165.0       112.0         1.3333            187500.0
# 18875      7025.0      2168.0         5.8171            225200.0
#
#       ocean_proximity income_cat
# 2224           INLAND          4
# 14896      NEAR OCEAN          2
# ...

# %%
df['income_cat'].hist( figsize=(9,5))
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np

np.random.seed(42)  # For reproducibility
data = {
    'feature': np.random.randn(30),  # Example feature data
    'class_label': np.random.choice(['A', 'B', 'C'], size=30)  # Random class labels
}
df = pd.DataFrame(data)

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in sss.split(df['feature'], df['class_label']):
    train_set = df.iloc[train_index]
    test_set = df.iloc[test_index]

# %%
test_set
# Out:
#      feature class_label
# 26 -1.150994           A
# 1  -0.138264           C
# 10 -0.463418           B
# 20  1.465649           B
# 12  0.241962           B
# 4  -0.234153           C

# %%
print(sss.split(df['feature'], df['class_label']))
# Out:
# <generator object BaseShuffleSplit.split at 0x7a6ba95b8a50>

# %%
df['class_label'].hist()
plt.show()

# %%
train_set['class_label'].hist()
plt.show()

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   income_cat
# 0          5
# 1          5
# 2          5
# ...

# %%
df2=df[['housing_median_age','population','households','median_income','median_house_value','total_rooms','total_bedrooms']]
df2.corr()
# Out:
#                     housing_median_age  population  households  median_income  \
# housing_median_age            1.000000   -0.296244   -0.302916      -0.119034
# population                   -0.296244    1.000000    0.907222       0.004834
# households                   -0.302916    0.907222    1.000000       0.013033
# median_income                -0.119034    0.004834    0.013033       1.000000
# median_house_value            0.105623   -0.024650    0.065843       0.688075
# total_rooms                  -0.361262    0.857126    0.918484       0.198050
# total_bedrooms               -0.320451    0.877747    0.979728      -0.007723
#
#                     median_house_value  total_rooms  total_bedrooms
# housing_median_age            0.105623    -0.361262       -0.320451
# population                   -0.024650     0.857126        0.877747
# households                    0.065843     0.918484        0.979728
# median_income                 0.688075     0.198050       -0.007723
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(), cmap='Accent', linewidths=0.3,square=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(df,x=df. cmap='Accent', linewidths=0.3,square=True)
plt.show()

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   income_cat
# 0          5
# 1          5
# 2          5
# ...

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df,y='median_income',x='housing_median_age')
plt.show()

# %%
for train_index, test_index in sss.split(df['feature'], df['class_label']):
    trainset=train_index
    testset=test_index

# %%
trainset
# Out:
# array([22, 11, 27,  9, 23,  5, 17,  2, 14,  6, 24,  7, 25, 18,  0, 28, 29,
#        15,  3, 13, 21, 16,  8, 19])

# %%
testset
# Out:
# array([26,  1, 10, 20, 12,  4])
